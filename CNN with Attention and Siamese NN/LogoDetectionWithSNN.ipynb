# %% [markdown]
# # Finding Logos in Screenshots
#
# Our method is
#
# 1. train a neural net to recognize company logos
# 2. use selective search for region proposal on screenshots
# 3. feed all proposed regions into neural net; if highest probability beats some threshold, count as positive ID

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import time
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Loading a Neural Net
#
# We train neural nets in the notebook TransferLearningLogoDetection and save the models in
#
# > /content/drive/MyDrive/LogoDetection/Models
#
# The models are saved using PyTorch, and they only save the state dicts, so we need to define an appropriate model first, then load the learnable parameters from the file.

# %% [markdown]
# Here is the Siamese NN class.

# %%
class Siamese(nn.Module):

    def __init__(self, conv, lin_in, lin_out):
        super(Siamese, self).__init__()
        self.conv = conv
        self.linear = nn.Sequential(nn.Linear(lin_in, lin_out), nn.Sigmoid())
        self.out = nn.Linear(lin_out, 1)

    def forward_one(self, x):
        x = self.conv(x)
        x = x.view(x.size()[0], -1)
        x = self.linear(x)
        return x

    def forward(self, x1, x2):
        out1 = self.forward_one(x1)
        out2 = self.forward_one(x2)
        dis = torch.abs(out1 - out2)
        out = self.out(dis)
        return out

# %%
class Siamese(nn.Module):

    def __init__(self, conv, lin_in, lin_out):
        super(Siamese, self).__init__()
        self.conv = conv
        self.linear1 = nn.Sequential(nn.Linear(lin_in, lin_out), nn.Sigmoid())
        self.linear2 = nn.Sequential(nn.Linear(lin_out, 32), nn.Sigmoid())

    def forward_one(self, x):
        x = self.conv(x)
        x = x.view(x.size()[0], -1)
        x = self.linear1(x)
        x = self.linear2(x)
        return x

    def forward(self, x1, x2):
        out1 = self.forward_one(x1)
        out2 = self.forward_one(x2)
        dis = torch.linalg.norm(out1 - out2, ord=2, dim=1).unsqueeze(1)
        #dis = torch.sum(torch.abs(out1 - out2), dim=1, keepdim=True)
        return dis

# %%
conv = None
lin_in = None
lin_out = None
img_size = None

# change CNN_type to choose from list below
CNN_type = 1

# example with the convolutional neural net from the one-shot Omniglot paper
#   Koch, Gregory, Richard Zemel, and Ruslan Salakhutdinov.
#   "Siamese neural networks for one-shot image recognition."
#   ICML deep learning workshop. Vol. 2. 2015.
# (modified to take 3-channel RGB input)
if CNN_type == 0 :
  conv = nn.Sequential(
          nn.Conv2d(3, 64, 10),  # 64@96*96
          nn.ReLU(inplace=True),
          nn.MaxPool2d(2),  # 64@48*48
          nn.Conv2d(64, 128, 7),
          nn.ReLU(),    # 128@42*42
          nn.MaxPool2d(2),   # 128@21*21
          nn.Conv2d(128, 128, 4),
          nn.ReLU(), # 128@18*18
          nn.MaxPool2d(2), # 128@9*9
          nn.Conv2d(128, 256, 4),
          nn.ReLU(),   # 256@6*6
          )
  lin_in = 9216
  lin_out = 4096
  img_size = (105, 105)

elif CNN_type == 1 :
  conv = models.resnet50(pretrained=True)
  for param in conv.parameters() :
    param.requires_grad = False

  lin_in = 1000
  lin_out = 500
  img_size=(244, 244)

else :
  raise ValueError("CNN_type = " + str(CNN_type) + " not valid.")

model = Siamese(conv, lin_in, lin_out)

state_dict = torch.load('/content/drive/MyDrive/LogoDetection/Models/siameseNet05.pt')
model.load_state_dict(state_dict)
model.cuda()
model.eval()
print('Model loaded.')
# Out:
# Model loaded.

# %% [markdown]
# ## Region Proposal and Evaluation
#
# For each image, we apply region proposal followed by feeding each region into the neural network.
# For region proposal, we use the selective search algorithm as implemented in OpenCV with the YOLO (you only look once) strategy.
# To use the neural network, we must compare the proposed region to each true logo.

# %% [markdown]
# The screenshots of websites and the true logos are stored on the Google drive.

# %%
ss_path = '/content/drive/MyDrive/LogoDetection/phishIRIS_DL_Dataset-logos_only/train'
logos_path = '/content/drive/MyDrive/LogoDetection/Logos'

# %%
# first, run the net on each true logo
logo_vecs = {}

transform = transforms.Compose([transforms.Resize(img_size),
                                transforms.ToTensor()])

for img_file in os.listdir(logos_path) :
  filepath = os.path.join(logos_path, img_file)
  img = Image.open(filepath).convert('RGB')
  img_t = transform(img).cuda()
  logo_vecs[img_file] = model.forward_one(img_t.unsqueeze(0))

# %% [markdown]
# Here's the main loop! We save results in /content/drive/MyDrive/LogoDetection/Results/siameseNetnn_results.csv.

# %%
display_progress = 1
test_mode = 0

# here is the file we'll be writing results to
f = None
if test_mode == 0 :
  f = open('/content/drive/MyDrive/LogoDetection/Results/siameseNet05_results.csv', 'w')
  f.write('img_name,pred_class,pred_prob,true_class\n')

# here's OpenCV's selective search object
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# will need to map numpy images to tensors
to_tensor = transforms.ToTensor()

# here is the required resize transform for our model
#   NOTE: size is defined with the model
transform = transforms.Resize(img_size)

# loop through all folders in the dataset (note: the folder defines the
# classification)
i = 0
for dir_name in os.listdir(ss_path) :
  print('')
  print('Working in directory ' + dir_name)

  # loop through images (only 10 if in test mode)
  img_names = os.listdir(os.path.join(ss_path, dir_name))
  if test_mode :
    R = 10
  else :
    R = len(img_names)
  for j in range(R) :
    # load image
    img_name = img_names[j]
    img = plt.imread(os.path.join(ss_path, dir_name, img_name))
    img_cv = cv2.cvtColor(img, cv2.COLOR_RGBA2RGB)
    img_t = to_tensor(img_cv)
    img_t = img_t.cuda()
    if display_progress :
      i += 1
      print('Loaded image ' + str(i) + ': ' + img_name +'.', end='... ')

    # run region proposal
    a = time.time()

    ss.setBaseImage(img_cv)
    ss.switchToSingleStrategy()
    rects = ss.process()

    b = time.time()
    if display_progress :
      print('Completed region proposal. %.2f sec.' % (b - a), end='... ')

    # because of memory issues, let's split the collection up by doing K
    # rectangles at a time
    K = 10
    num_rects_total = len(rects)
    #num_rects_total = min(len(rects), 200)
    num_groups = int(num_rects_total/K)
    num_extra = num_rects_total % K

    best_dsim = np.inf
    best_class = -1

    for j in range(num_groups) :

      # grab subset of the rectangles
      rects_temp = rects[j*K:(j+1)*K]
      if j == num_groups - 1 :
        rects_temp = rects[j*K:(j+1)*K + num_extra]

      # set up tensor to hold rectangles
      imgs = torch.zeros(len(rects_temp), 3, img_size[0], img_size[1])
      imgs = imgs.cuda()

      # load rectangles
      for n, (x, y, w, h) in enumerate(rects_temp) :
        img = img_t[:, y:y+h, x:x+w]
        img = img.cuda()
        img = transform(img)
        imgs[n, :, :, :] = img

      # get feature vecotrs for images
      img_vecs = model.forward_one(imgs)

      # compare against each logo
      for key, value in logo_vecs.items() :
        #dis = torch.abs(img_vecs - value)
        #out = model.out(dis)
        #prob_preds = torch.sigmoid(out)
        #prob_pred = torch.max(prob_preds)

        dis = torch.linalg.norm(img_vecs - value, ord=2, dim=1).unsqueeze(1)
        #dis = torch.sum(torch.abs(img_vecs - value), dim=1, keepdim=True)
        min_dsim = torch.min(dis)

        if min_dsim < best_dsim :
          best_dsim = min_dsim
          best_class = key

    c = time.time()
    if display_progress :
      print('Completed prediction. %.2f sec.' % (c - b))

    result_message = 'Aww :('
    if best_class.split('.')[0].split('_')[0] == dir_name :
      result_message = 'Woo! :D'

    # save prediction and probability
    if display_progress :
      print('Dissimilarity score: ' + str(best_dsim.item()) + ',  Class predicted: ' + best_class + ',   ' + result_message)
    if test_mode == 0 :
      f.write(img_name + ',' + best_class + ',' + str(best_dsim.item()) + ',' + dir_name + '\n')

if test_mode == 0:
  f.close()
# Out:
# Working in directory apple
# Loaded image 1: apple (48).png.... Completed region proposal. 0.84 sec.... Completed prediction. 0.42 sec.
# Dissimilarity score: 0.411774218082428,  Class predicted: microsoft_3.png,   Aww :(
# Loaded image 2: apple (49).png.... Completed region proposal. 0.77 sec.... Completed prediction. 0.23 sec.
# Dissimilarity score: 0.4734462797641754,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 3: apple (1).png.... Completed region proposal. 1.05 sec.... Completed prediction. 0.44 sec.
# Dissimilarity score: 0.44330814480781555,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 4: apple (2).png.... Completed region proposal. 2.00 sec.... Completed prediction. 1.49 sec.
# Dissimilarity score: 0.37645450234413147,  Class predicted: amazon_1.png,   Aww :(
# Loaded image 5: apple (3).png.... Completed region proposal. 1.11 sec.... Completed prediction. 0.56 sec.
# Dissimilarity score: 0.6068193912506104,  Class predicted: adobe_2.png,   Aww :(
# Loaded image 6: apple (15).png.... Completed region proposal. 1.61 sec.... Completed prediction. 0.69 sec.
# Dissimilarity score: 0.29540514945983887,  Class predicted: adobe_2.png,   Aww :(
# Loaded image 7: apple (30).png.... Completed region proposal. 1.28 sec.... Completed prediction. 0.34 sec.
# Dissimilarity score: 0.4217331111431122,  Class predicted: paypal_1.png,   Aww :(
# Loaded image 8: apple (16).png.... Completed region proposal. 3.07 sec.... Completed prediction. 1.93 sec.
# Dissimilarity score: 0.4400821924209595,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 9: apple (31).png.... Completed region proposal. 1.47 sec.... Completed prediction. 0.45 sec.
# Dissimilarity score: 0.6562718749046326,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 10: apple (32).png.... Completed region proposal. 1.46 sec.... Completed prediction. 0.45 sec.
# Dissimilarity score: 0.19883812963962555,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 11: apple (33).png.... Completed region proposal. 1.28 sec.... Completed prediction. 0.28 sec.
# Dissimilarity score: 0.31980085372924805,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 12: apple (46).png.... Completed region proposal. 1.40 sec.... Completed prediction. 0.36 sec.
# Dissimilarity score: 0.4721314311027527,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 13: apple (17).png.... Completed region proposal. 1.41 sec.... Completed prediction. 0.41 sec.
# Dissimilarity score: 0.35534319281578064,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 14: apple (18).png.... Completed region proposal. 1.43 sec.... Completed prediction. 0.41 sec.
# Dissimilarity score: 0.35534319281578064,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 15: apple (19).png.... Completed region proposal. 0.94 sec.... Completed prediction. 0.09 sec.
# Dissimilarity score: 0.5496042370796204,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 16: apple (34).png.... Completed region proposal. 1.78 sec.... Completed prediction. 0.70 sec.
# Dissimilarity score: 0.3781869411468506,  Class predicted: adobe_2.png,   Aww :(
# Loaded image 17: apple (35).png.... Completed region proposal. 1.27 sec.... Completed prediction. 0.29 sec.
# Dissimilarity score: 0.31980085372924805,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 18: apple (20).png.... Completed region proposal. 1.37 sec.... Completed prediction. 0.41 sec.
# Dissimilarity score: 0.35534319281578064,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 19: apple (21).png.... Completed region proposal. 2.46 sec.... Completed prediction. 1.75 sec.
# Dissimilarity score: 0.3906336724758148,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 20: apple (22).png.... Completed region proposal. 1.89 sec.... Completed prediction. 1.04 sec.
# Dissimilarity score: 0.43913429975509644,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 21: apple (23).png.... Completed region proposal. 2.44 sec.... Completed prediction. 1.54 sec.
# Dissimilarity score: 0.32811203598976135,  Class predicted: yahoo_2.png,   Aww :(
# Loaded image 22: apple (47).png.... Completed region proposal. 1.94 sec.... Completed prediction. 0.81 sec.
# Dissimilarity score: 0.5207089185714722,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 23: apple (24).png.... Completed region proposal. 1.64 sec.... Completed prediction. 0.25 sec.
# Dissimilarity score: 0.5012026429176331,  Class predicted: microsoft_4.png,   Aww :(
# Loaded image 24: apple (36).png.... Completed region proposal. 1.77 sec.... Completed prediction. 0.67 sec.
# Dissimilarity score: 0.3781869411468506,  Class predicted: adobe_2.png,   Aww :(
# Loaded image 25: apple (37).png.... Completed region proposal. 1.76 sec.... Completed prediction. 0.66 sec.
# Dissimilarity score: 0.3781869411468506,  Class predicted: adobe_2.png,   Aww :(
# Loaded image 26: apple (25).png.... Completed region proposal. 1.13 sec.... Completed prediction. 0.33 sec.
# Dissimilarity score: 0.5189167857170105,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 27: apple (26).png.... Completed region proposal. 1.31 sec.... Completed prediction. 0.57 sec.
# Dissimilarity score: 0.3060854971408844,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 28: apple (27).png.... Completed region proposal. 1.63 sec.... Completed prediction. 0.79 sec.
# Dissimilarity score: 0.39655864238739014,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 29: apple (28).png.... Completed region proposal. 2.53 sec.... Completed prediction. 1.82 sec.
# Dissimilarity score: 0.3906336724758148,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 30: apple (29).png.... Completed region proposal. 1.77 sec.... Completed prediction. 0.98 sec.
# Dissimilarity score: 0.43913429975509644,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 31: apple (39).png.... Completed region proposal. 1.54 sec.... Completed prediction. 0.58 sec.
# Dissimilarity score: 0.31980085372924805,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 32: apple (38).png.... Completed region proposal. 1.52 sec.... Completed prediction. 0.59 sec.
# Dissimilarity score: 0.31980085372924805,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 33: apple (41).png.... Completed region proposal. 1.70 sec.... Completed prediction. 0.67 sec.
# Dissimilarity score: 0.31010493636131287,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 34: apple (40).png.... Completed region proposal. 1.72 sec.... Completed prediction. 0.67 sec.
# Dissimilarity score: 0.31010493636131287,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 35: apple (42).png.... Completed region proposal. 1.86 sec.... Completed prediction. 0.84 sec.
# Dissimilarity score: 0.5357125401496887,  Class predicted: boa_1.png,   Aww :(
# Loaded image 36: apple (43).png.... Completed region proposal. 1.88 sec.... Completed prediction. 0.83 sec.
# Dissimilarity score: 0.31980085372924805,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 37: apple (44).png.... Completed region proposal. 1.95 sec.... Completed prediction. 0.90 sec.
# Dissimilarity score: 0.36010944843292236,  Class predicted: boa_1.png,   Aww :(
# Loaded image 38: apple (45).png.... Completed region proposal. 1.88 sec.... Completed prediction. 0.84 sec.
# Dissimilarity score: 0.5357125401496887,  Class predicted: boa_1.png,   Aww :(
# Loaded image 39: apple (4).png.... Completed region proposal. 2.15 sec.... Completed prediction. 0.29 sec.
# Dissimilarity score: 0.4221752882003784,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 40: apple (13).png.... Completed region proposal. 1.64 sec.... Completed prediction. 0.16 sec.
# Dissimilarity score: 0.39521312713623047,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 41: apple (14).png.... Completed region proposal. 3.20 sec.... Completed prediction. 1.10 sec.
# Dissimilarity score: 0.6250643730163574,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 42: apple (5).png.... Completed region proposal. 5.30 sec.... Completed prediction. 2.29 sec.
# Dissimilarity score: 0.4051657021045685,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 43: apple (6).png.... Completed region proposal. 5.32 sec.... Completed prediction. 2.32 sec.
# Dissimilarity score: 0.4051657021045685,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 44: apple (8).png.... Completed region proposal. 2.85 sec.... Completed prediction. 0.72 sec.
# Dissimilarity score: 0.3127545416355133,  Class predicted: microsoft_4.png,   Aww :(
# Loaded image 45: apple (7).png.... Completed region proposal. 1.83 sec.... Completed prediction. 0.22 sec.
# Dissimilarity score: 0.47273826599121094,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 46: apple (10).png.... Completed region proposal. 6.37 sec.... Completed prediction. 3.01 sec.
# Dissimilarity score: 0.21908265352249146,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 47: apple (9).png.... Completed region proposal. 6.35 sec.... Completed prediction. 2.99 sec.
# Dissimilarity score: 0.21908265352249146,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 48: apple (11).png.... Completed region proposal. 5.34 sec.... Completed prediction. 2.25 sec.
# Dissimilarity score: 0.31609755754470825,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 49: apple (12).png.... Completed region proposal. 3.20 sec.... Completed prediction. 1.10 sec.
# Dissimilarity score: 0.6160752773284912,  Class predicted: microsoft_1.png,   Aww :(
#
# Working in directory microsoft
# Loaded image 50: microsoft (2).jpg.... Completed region proposal. 1.66 sec.... Completed prediction. 3.04 sec.
# Dissimilarity score: 0.3100864887237549,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 51: microsoft (63).png.... Completed region proposal. 1.75 sec.... Completed prediction. 0.22 sec.
# Dissimilarity score: 0.5301222205162048,  Class predicted: boa_1.png,   Aww :(
# Loaded image 52: microsoft (1).jpg.... Completed region proposal. 1.60 sec.... Completed prediction. 1.44 sec.
# Dissimilarity score: 0.3060758411884308,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 53: microsoft (1).png.... Completed region proposal. 0.95 sec.... Completed prediction. 0.29 sec.
# Dissimilarity score: 0.4919840693473816,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 54: microsoft (2).png.... Completed region proposal. 1.11 sec.... Completed prediction. 0.53 sec.
# Dissimilarity score: 0.46668004989624023,  Class predicted: paypal_1.png,   Aww :(
# Loaded image 55: microsoft (4).png.... Completed region proposal. 1.53 sec.... Completed prediction. 1.07 sec.
# Dissimilarity score: 0.4065106511116028,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 56: microsoft (3).png.... Completed region proposal. 1.52 sec.... Completed prediction. 1.06 sec.
# Dissimilarity score: 0.4065106511116028,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 57: microsoft (21).png.... Completed region proposal. 3.97 sec.... Completed prediction. 2.62 sec.
# Dissimilarity score: 0.2629283666610718,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 58: microsoft (23).png.... Completed region proposal. 1.06 sec.... Completed prediction. 0.28 sec.
# Dissimilarity score: 0.3931078016757965,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 59: microsoft (24).png.... Completed region proposal. 1.27 sec.... Completed prediction. 0.48 sec.
# Dissimilarity score: 0.5446920990943909,  Class predicted: boa_1.png,   Aww :(
# Loaded image 60: microsoft (25).png.... Completed region proposal. 1.10 sec.... Completed prediction. 0.34 sec.
# Dissimilarity score: 0.17232197523117065,  Class predicted: microsoft_2.png,   Woo! :D
# Loaded image 61: microsoft (26).png.... Completed region proposal. 2.68 sec.... Completed prediction. 1.93 sec.
# Dissimilarity score: 0.3813434839248657,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 62: microsoft (27).png.... Completed region proposal. 2.52 sec.... Completed prediction. 1.85 sec.
# Dissimilarity score: 0.33870789408683777,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 63: microsoft (28).png.... Completed region proposal. 2.53 sec.... Completed prediction. 1.82 sec.
# Dissimilarity score: 0.33870789408683777,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 64: microsoft (29).png.... Completed region proposal. 2.62 sec.... Completed prediction. 1.83 sec.
# Dissimilarity score: 0.33870789408683777,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 65: microsoft (30).png.... Completed region proposal. 1.16 sec.... Completed prediction. 0.38 sec.
# Dissimilarity score: 0.5049324631690979,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 66: microsoft (31).png.... Completed region proposal. 1.14 sec.... Completed prediction. 0.38 sec.
# Dissimilarity score: 0.5049324631690979,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 67: microsoft (32).png.... Completed region proposal. 2.73 sec.... Completed prediction. 1.96 sec.
# Dissimilarity score: 0.3813434839248657,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 68: microsoft (33).png.... Completed region proposal. 1.70 sec.... Completed prediction. 0.60 sec.
# Dissimilarity score: 0.4019646942615509,  Class predicted: boa_1.png,   Aww :(
# Loaded image 69: microsoft (34).png.... Completed region proposal. 1.25 sec.... Completed prediction. 0.27 sec.
# Dissimilarity score: 0.3931078016757965,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 70: microsoft (35).png.... Completed region proposal. 1.33 sec.... Completed prediction. 0.32 sec.
# Dissimilarity score: 0.3931078016757965,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 71: microsoft (37).png.... Completed region proposal. 2.50 sec.... Completed prediction. 1.80 sec.
# Dissimilarity score: 0.33870789408683777,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 72: microsoft (38).png.... Completed region proposal. 1.14 sec.... Completed prediction. 0.39 sec.
# Dissimilarity score: 0.5049324631690979,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 73: microsoft (39).png.... Completed region proposal. 2.74 sec.... Completed prediction. 1.96 sec.
# Dissimilarity score: 0.3813434839248657,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 74: microsoft (40).png.... Completed region proposal. 1.11 sec.... Completed prediction. 0.34 sec.
# Dissimilarity score: 0.17232197523117065,  Class predicted: microsoft_2.png,   Woo! :D
# Loaded image 75: microsoft (41).png.... Completed region proposal. 1.10 sec.... Completed prediction. 0.33 sec.
# Dissimilarity score: 0.17232197523117065,  Class predicted: microsoft_2.png,   Woo! :D
# Loaded image 76: microsoft (42).png.... Completed region proposal. 1.09 sec.... Completed prediction. 0.32 sec.
# Dissimilarity score: 0.4099993109703064,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 77: microsoft (44).png.... Completed region proposal. 1.59 sec.... Completed prediction. 0.87 sec.
# Dissimilarity score: 0.4137454926967621,  Class predicted: paypal_1.png,   Aww :(
# Loaded image 78: microsoft (43).png.... Completed region proposal. 2.43 sec.... Completed prediction. 1.73 sec.
# Dissimilarity score: 0.4142608642578125,  Class predicted: facebook_2.png,   Aww :(
# Loaded image 79: microsoft (45).png.... Completed region proposal. 2.73 sec.... Completed prediction. 1.97 sec.
# Dissimilarity score: 0.2802010476589203,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 80: microsoft (46).png.... Completed region proposal. 1.75 sec.... Completed prediction. 0.61 sec.
# Dissimilarity score: 0.4019646942615509,  Class predicted: boa_1.png,   Aww :(
# Loaded image 81: microsoft (48).png.... Completed region proposal. 2.15 sec.... Completed prediction. 1.38 sec.
# Dissimilarity score: 0.36716771125793457,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 82: microsoft (49).png.... Completed region proposal. 2.77 sec.... Completed prediction. 1.97 sec.
# Dissimilarity score: 0.2802010476589203,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 83: microsoft (51).png.... Completed region proposal. 3.15 sec.... Completed prediction. 2.10 sec.
# Dissimilarity score: 0.2931654751300812,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 84: microsoft (50).png.... Completed region proposal. 3.09 sec.... Completed prediction. 2.10 sec.
# Dissimilarity score: 0.2931654751300812,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 85: microsoft (52).png.... Completed region proposal. 1.40 sec.... Completed prediction. 0.52 sec.
# Dissimilarity score: 0.43957632780075073,  Class predicted: wellsfargo_1.png,   Aww :(
# Loaded image 86: microsoft (53).png.... Completed region proposal. 1.39 sec.... Completed prediction. 0.53 sec.
# Dissimilarity score: 0.43957632780075073,  Class predicted: wellsfargo_1.png,   Aww :(
# Loaded image 87: microsoft (54).png.... Completed region proposal. 0.90 sec.... Completed prediction. 0.16 sec.
# Dissimilarity score: 0.4617066979408264,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 88: microsoft (55).png.... Completed region proposal. 2.66 sec.... Completed prediction. 1.87 sec.
# Dissimilarity score: 0.35699662566185,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 89: microsoft (56).png.... Completed region proposal. 2.56 sec.... Completed prediction. 1.82 sec.
# Dissimilarity score: 0.33870789408683777,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 90: microsoft (57).png.... Completed region proposal. 2.29 sec.... Completed prediction. 1.43 sec.
# Dissimilarity score: 0.45926418900489807,  Class predicted: microsoft_3.png,   Woo! :D
# Loaded image 91: microsoft (58).png.... Completed region proposal. 0.91 sec.... Completed prediction. 0.13 sec.
# Dissimilarity score: 0.4617066979408264,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 92: microsoft (60).png.... Completed region proposal. 0.99 sec.... Completed prediction. 0.22 sec.
# Dissimilarity score: 0.5550768971443176,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 93: microsoft (59).png.... Completed region proposal. 1.02 sec.... Completed prediction. 0.22 sec.
# Dissimilarity score: 0.5550768971443176,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 94: microsoft (61).png.... Completed region proposal. 2.68 sec.... Completed prediction. 1.58 sec.
# Dissimilarity score: 0.4263499975204468,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 95: microsoft (62).png.... Completed region proposal. 2.66 sec.... Completed prediction. 1.58 sec.
# Dissimilarity score: 0.4263499975204468,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 96: microsoft (6).png.... Completed region proposal. 2.81 sec.... Completed prediction. 0.67 sec.
# Dissimilarity score: 0.3957822322845459,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 97: microsoft (9).png.... Completed region proposal. 1.65 sec.... Completed prediction. 0.14 sec.
# Dissimilarity score: 0.4910965859889984,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 98: microsoft (10).png.... Completed region proposal. 1.63 sec.... Completed prediction. 0.14 sec.
# Dissimilarity score: 0.4910965859889984,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 99: microsoft (11).png.... Completed region proposal. 3.31 sec.... Completed prediction. 0.94 sec.
# Dissimilarity score: 0.407978355884552,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 100: microsoft (7).png.... Completed region proposal. 3.36 sec.... Completed prediction. 0.94 sec.
# Dissimilarity score: 0.407978355884552,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 101: microsoft (8).png.... Completed region proposal. 4.77 sec.... Completed prediction. 1.82 sec.
# Dissimilarity score: 0.3992292284965515,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 102: microsoft (12).png.... Completed region proposal. 1.91 sec.... Completed prediction. 0.21 sec.
# Dissimilarity score: 0.2609316408634186,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 103: microsoft (13).png.... Completed region proposal. 1.46 sec.... Completed prediction. 0.06 sec.
# Dissimilarity score: 0.6017348170280457,  Class predicted: chase_2.png,   Aww :(
# Loaded image 104: microsoft (14).png.... Completed region proposal. 2.37 sec.... Completed prediction. 0.54 sec.
# Dissimilarity score: 0.4698239862918854,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 105: microsoft (15).png.... Completed region proposal. 1.81 sec.... Completed prediction. 0.24 sec.
# Dissimilarity score: 0.305871844291687,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 106: microsoft (16).png.... Completed region proposal. 2.12 sec.... Completed prediction. 0.43 sec.
# Dissimilarity score: 0.4698239862918854,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 107: microsoft (17).png.... Completed region proposal. 1.59 sec.... Completed prediction. 0.11 sec.
# Dissimilarity score: 0.7243097424507141,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 108: microsoft (18).png.... Completed region proposal. 5.27 sec.... Completed prediction. 2.33 sec.
# Dissimilarity score: 0.3934299945831299,  Class predicted: microsoft_1.png,   Woo! :D
# Loaded image 109: microsoft (19).png.... Completed region proposal. 2.55 sec.... Completed prediction. 0.72 sec.
# Dissimilarity score: 0.3700525164604187,  Class predicted: microsoft_4.png,   Woo! :D
# Loaded image 110: microsoft (5).png.... Completed region proposal. 1.87 sec.... Completed prediction. 0.19 sec.
# Dissimilarity score: 0.41333162784576416,  Class predicted: microsoft_1.png,   Woo! :D
#
# Working in directory paypal
# Loaded image 111: paypal (25).jpg.... Completed region proposal. 3.31 sec.... Completed prediction. 1.82 sec.
# Dissimilarity score: 0.27836745977401733,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 112: paypal (26).jpg.... Completed region proposal. 3.32 sec.... Completed prediction. 1.85 sec.
# Dissimilarity score: 0.27836745977401733,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 113: paypal (23).jpg.... Completed region proposal. 1.15 sec.... Completed prediction. 0.53 sec.
# Dissimilarity score: 0.401267409324646,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 114: paypal (22).jpg.... Completed region proposal. 1.06 sec.... Completed prediction. 0.57 sec.
# Dissimilarity score: 0.401267409324646,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 115: paypal (21).jpg.... Completed region proposal. 1.03 sec.... Completed prediction. 0.57 sec.
# Dissimilarity score: 0.401267409324646,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 116: paypal (24).jpg.... Completed region proposal. 1.78 sec.... Completed prediction. 1.46 sec.
# Dissimilarity score: 0.3456006646156311,  Class predicted: boa_2.png,   Aww :(
# Loaded image 117: paypal (33).png.... Completed region proposal. 12.02 sec.... Completed prediction. 3.89 sec.
# Dissimilarity score: 0.31400683522224426,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 118: paypal (27).jpg.... Completed region proposal. 1.19 sec.... Completed prediction. 0.77 sec.
# Dissimilarity score: 0.5031254887580872,  Class predicted: boa_1.png,   Aww :(
# Loaded image 119: paypal (48).jpg.... Completed region proposal. 1.15 sec.... Completed prediction. 0.76 sec.
# Dissimilarity score: 0.3687543570995331,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 120: paypal (28).jpg.... Completed region proposal. 1.74 sec.... Completed prediction. 1.28 sec.
# Dissimilarity score: 0.4720660448074341,  Class predicted: dropbox_2.png,   Aww :(
# Loaded image 121: paypal (11).jpg.... Completed region proposal. 1.68 sec.... Completed prediction. 1.38 sec.
# Dissimilarity score: 0.3272501528263092,  Class predicted: yahoo_2.png,   Aww :(
# Loaded image 122: paypal (12).jpg.... Completed region proposal. 1.62 sec.... Completed prediction. 1.38 sec.
# Dissimilarity score: 0.3272501528263092,  Class predicted: yahoo_2.png,   Aww :(
# Loaded image 123: paypal (34).png.... Completed region proposal. 1.80 sec.... Completed prediction. 0.88 sec.
# Dissimilarity score: 0.535047173500061,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 124: paypal (13).jpg.... Completed region proposal. 0.73 sec.... Completed prediction. 0.18 sec.
# Dissimilarity score: 0.5091943740844727,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 125: paypal (15).jpg.... Completed region proposal. 2.92 sec.... Completed prediction. 2.65 sec.
# Dissimilarity score: 0.40549978613853455,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 126: paypal (14).jpg.... Completed region proposal. 2.95 sec.... Completed prediction. 2.61 sec.
# Dissimilarity score: 0.40549978613853455,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 127: paypal (45).jpg.... Completed region proposal. 3.07 sec.... Completed prediction. 2.36 sec.
# Dissimilarity score: 0.34517672657966614,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 128: paypal (29).png.... Completed region proposal. 7.67 sec.... Completed prediction. 4.42 sec.
# Dissimilarity score: 0.35382160544395447,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 129: paypal (30).png.... Completed region proposal. 7.65 sec.... Completed prediction. 4.39 sec.
# Dissimilarity score: 0.35382160544395447,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 130: paypal (19).jpg.... Completed region proposal. 3.78 sec.... Completed prediction. 2.25 sec.
# Dissimilarity score: 0.40015116333961487,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 131: paypal (20).jpg.... Completed region proposal. 3.84 sec.... Completed prediction. 2.23 sec.
# Dissimilarity score: 0.40015116333961487,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 132: paypal (20).png.... Completed region proposal. 4.59 sec.... Completed prediction. 1.08 sec.
# Dissimilarity score: 0.42996343970298767,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 133: paypal (21).png.... Completed region proposal. 4.59 sec.... Completed prediction. 1.09 sec.
# Dissimilarity score: 0.42996343970298767,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 134: paypal (30).jpg.... Completed region proposal. 1.43 sec.... Completed prediction. 1.00 sec.
# Dissimilarity score: 0.34706780314445496,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 135: paypal (33).jpg.... Completed region proposal. 1.08 sec.... Completed prediction. 0.47 sec.
# Dissimilarity score: 0.43835484981536865,  Class predicted: microsoft_2.png,   Aww :(
# Loaded image 136: paypal (34).jpg.... Completed region proposal. 1.07 sec.... Completed prediction. 0.48 sec.
# Dissimilarity score: 0.43835484981536865,  Class predicted: microsoft_2.png,   Aww :(
# Loaded image 137: paypal (47).jpg.... Completed region proposal. 2.83 sec.... Completed prediction. 3.26 sec.
# Dissimilarity score: 0.541396975517273,  Class predicted: yahoo_1.png,   Aww :(
# Loaded image 138: paypal (46).jpg.... Completed region proposal. 2.86 sec.... Completed prediction. 3.26 sec.
# Dissimilarity score: 0.541396975517273,  Class predicted: yahoo_1.png,   Aww :(
# Loaded image 139: paypal (22).png.... Completed region proposal. 5.49 sec.... Completed prediction. 3.05 sec.
# Dissimilarity score: 0.5295491218566895,  Class predicted: boa_1.png,   Aww :(
# Loaded image 140: paypal (23).png.... Completed region proposal. 5.50 sec.... Completed prediction. 3.04 sec.
# Dissimilarity score: 0.5295491218566895,  Class predicted: boa_1.png,   Aww :(
# Loaded image 141: paypal (35).jpg.... Completed region proposal. 0.93 sec.... Completed prediction. 0.43 sec.
# Dissimilarity score: 0.5162642002105713,  Class predicted: yahoo_1.png,   Aww :(
# Loaded image 142: paypal (37).jpg.... Completed region proposal. 1.39 sec.... Completed prediction. 1.08 sec.
# Dissimilarity score: 0.21280771493911743,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 143: paypal (36).jpg.... Completed region proposal. 1.39 sec.... Completed prediction. 1.07 sec.
# Dissimilarity score: 0.21280771493911743,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 144: paypal (40).jpg.... Completed region proposal. 0.84 sec.... Completed prediction. 0.32 sec.
# Dissimilarity score: 0.596006453037262,  Class predicted: chase_2.png,   Aww :(
# Loaded image 145: paypal (41).jpg.... Completed region proposal. 0.85 sec.... Completed prediction. 0.33 sec.
# Dissimilarity score: 0.5960068702697754,  Class predicted: chase_2.png,   Aww :(
# Loaded image 146: paypal (32).png.... Completed region proposal. 3.12 sec.... Completed prediction. 0.60 sec.
# Dissimilarity score: 0.40521669387817383,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 147: paypal (38).jpg.... Completed region proposal. 1.77 sec.... Completed prediction. 1.42 sec.
# Dissimilarity score: 0.34919923543930054,  Class predicted: boa_1.png,   Aww :(
# Loaded image 148: paypal (39).jpg.... Completed region proposal. 1.77 sec.... Completed prediction. 1.43 sec.
# Dissimilarity score: 0.34919923543930054,  Class predicted: boa_1.png,   Aww :(
# Loaded image 149: paypal (18).png.... Completed region proposal. 11.02 sec.... Completed prediction. 2.94 sec.
# Dissimilarity score: 0.2857731878757477,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 150: paypal (19).png.... Completed region proposal. 11.38 sec.... Completed prediction. 3.00 sec.
# Dissimilarity score: 0.2857731878757477,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 151: paypal (42).jpg.... Completed region proposal. 3.95 sec.... Completed prediction. 2.17 sec.
# Dissimilarity score: 0.3607606291770935,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 152: paypal (44).jpg.... Completed region proposal. 1.30 sec.... Completed prediction. 0.93 sec.
# Dissimilarity score: 0.21280771493911743,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 153: paypal (26).png.... Completed region proposal. 3.17 sec.... Completed prediction. 1.08 sec.
# Dissimilarity score: 0.3670993447303772,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 154: paypal (27).png.... Completed region proposal. 3.22 sec.... Completed prediction. 1.07 sec.
# Dissimilarity score: 0.3670993447303772,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 155: paypal (36).png.... Completed region proposal. 1.06 sec.... Completed prediction. 0.28 sec.
# Dissimilarity score: 0.618869423866272,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 156: paypal (31).png.... Completed region proposal. 3.41 sec.... Completed prediction. 0.75 sec.
# Dissimilarity score: 0.4859798848628998,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 157: paypal (25).png.... Completed region proposal. 6.61 sec.... Completed prediction. 3.46 sec.
# Dissimilarity score: 0.3320632576942444,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 158: paypal (35).png.... Completed region proposal. 9.88 sec.... Completed prediction. 3.46 sec.
# Dissimilarity score: 0.3307999074459076,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 159: paypal (17).png.... Completed region proposal. 0.95 sec.... Completed prediction. 0.51 sec.
# Dissimilarity score: 0.43082287907600403,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 160: paypal (15).png.... Completed region proposal. 1.20 sec.... Completed prediction. 0.77 sec.
# Dissimilarity score: 0.25075387954711914,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 161: paypal (16).png.... Completed region proposal. 1.19 sec.... Completed prediction. 0.77 sec.
# Dissimilarity score: 0.25075387954711914,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 162: paypal (17).jpg.... Completed region proposal. 2.94 sec.... Completed prediction. 3.05 sec.
# Dissimilarity score: 0.24936187267303467,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 163: paypal (16).jpg.... Completed region proposal. 2.91 sec.... Completed prediction. 3.06 sec.
# Dissimilarity score: 0.24936187267303467,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 164: paypal (24).png.... Completed region proposal. 1.65 sec.... Completed prediction. 0.86 sec.
# Dissimilarity score: 0.2649149000644684,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 165: paypal (18).jpg.... Completed region proposal. 2.31 sec.... Completed prediction. 1.66 sec.
# Dissimilarity score: 0.3139491677284241,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 166: paypal (43).jpg.... Completed region proposal. 4.33 sec.... Completed prediction. 3.41 sec.
# Dissimilarity score: 0.3988381028175354,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 167: paypal (8).png.... Completed region proposal. 4.42 sec.... Completed prediction. 1.64 sec.
# Dissimilarity score: 0.3577335476875305,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 168: paypal (28).png.... Completed region proposal. 4.22 sec.... Completed prediction. 1.59 sec.
# Dissimilarity score: 0.3577335476875305,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 169: paypal (29).jpg.... Completed region proposal. 2.00 sec.... Completed prediction. 1.06 sec.
# Dissimilarity score: 0.2999474108219147,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 170: paypal (31).jpg.... Completed region proposal. 2.63 sec.... Completed prediction. 1.95 sec.
# Dissimilarity score: 0.4377277195453644,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 171: paypal (32).jpg.... Completed region proposal. 2.61 sec.... Completed prediction. 1.96 sec.
# Dissimilarity score: 0.4377277195453644,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 172: paypal (9).jpg.... Completed region proposal. 1.46 sec.... Completed prediction. 1.18 sec.
# Dissimilarity score: 0.34394535422325134,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 173: paypal (10).jpg.... Completed region proposal. 1.03 sec.... Completed prediction. 0.60 sec.
# Dissimilarity score: 0.2180536389350891,  Class predicted: paypal_1.png,   Woo! :D
# Loaded image 174: paypal (6).png.... Completed region proposal. 0.97 sec.... Completed prediction. 0.36 sec.
# Dissimilarity score: 0.4090732932090759,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 175: paypal (4).jpg.... Completed region proposal. 1.14 sec.... Completed prediction. 0.72 sec.
# Dissimilarity score: 0.26528143882751465,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 176: paypal (7).jpg.... Completed region proposal. 2.40 sec.... Completed prediction. 2.33 sec.
# Dissimilarity score: 0.26012828946113586,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 177: paypal (8).jpg.... Completed region proposal. 1.48 sec.... Completed prediction. 1.00 sec.
# Dissimilarity score: 0.5149115324020386,  Class predicted: boa_1.png,   Aww :(
# Loaded image 178: paypal (6).jpg.... Completed region proposal. 3.77 sec.... Completed prediction. 2.85 sec.
# Dissimilarity score: 0.40189191699028015,  Class predicted: wellsfargo_2.png,   Aww :(
# Loaded image 179: paypal (5).jpg.... Completed region proposal. 3.73 sec.... Completed prediction. 2.86 sec.
# Dissimilarity score: 0.40189191699028015,  Class predicted: wellsfargo_2.png,   Aww :(
# Loaded image 180: paypal (1).jpg.... Completed region proposal. 2.43 sec.... Completed prediction. 2.38 sec.
# Dissimilarity score: 0.3423921763896942,  Class predicted: microsoft_3.png,   Aww :(
# Loaded image 181: paypal (2).jpg.... Completed region proposal. 2.47 sec.... Completed prediction. 2.38 sec.
# Dissimilarity score: 0.3423921763896942,  Class predicted: microsoft_3.png,   Aww :(
# Loaded image 182: paypal (3).jpg.... Completed region proposal. 1.18 sec.... Completed prediction. 0.67 sec.
# Dissimilarity score: 0.401267409324646,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 183: paypal (2).png.... Completed region proposal. 3.02 sec.... Completed prediction. 3.17 sec.
# Dissimilarity score: 0.36678171157836914,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 184: paypal (3).png.... Completed region proposal. 2.61 sec.... Completed prediction. 2.30 sec.
# Dissimilarity score: 0.29638537764549255,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 185: paypal (49).jpg.... Completed region proposal. 2.83 sec.... Completed prediction. 2.44 sec.
# Dissimilarity score: 0.4046398401260376,  Class predicted: paypal_1.png,   Woo! :D
# Loaded image 186: paypal (1).png.... Completed region proposal. 1.27 sec.... Completed prediction. 0.62 sec.
# Dissimilarity score: 0.3993183374404907,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 187: paypal (11).png.... Completed region proposal. 1.23 sec.... Completed prediction. 0.56 sec.
# Dissimilarity score: 0.3836672008037567,  Class predicted: microsoft_3.png,   Aww :(
# Loaded image 188: paypal (7).png.... Completed region proposal. 1.97 sec.... Completed prediction. 1.69 sec.
# Dissimilarity score: 0.2606193721294403,  Class predicted: dhl.png,   Aww :(
# Loaded image 189: paypal (13).png.... Completed region proposal. 0.85 sec.... Completed prediction. 0.43 sec.
# Dissimilarity score: 0.33036166429519653,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 190: paypal (55).png.... Completed region proposal. 1.32 sec.... Completed prediction. 0.61 sec.
# Dissimilarity score: 0.41294896602630615,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 191: paypal (56).png.... Completed region proposal. 1.33 sec.... Completed prediction. 0.61 sec.
# Dissimilarity score: 0.41294896602630615,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 192: paypal (57).png.... Completed region proposal. 1.08 sec.... Completed prediction. 0.33 sec.
# Dissimilarity score: 0.35557979345321655,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 193: paypal (58).png.... Completed region proposal. 1.10 sec.... Completed prediction. 0.32 sec.
# Dissimilarity score: 0.35557979345321655,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 194: paypal (59).png.... Completed region proposal. 1.12 sec.... Completed prediction. 0.32 sec.
# Dissimilarity score: 0.35557979345321655,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 195: paypal (60).png.... Completed region proposal. 3.11 sec.... Completed prediction. 2.31 sec.
# Dissimilarity score: 0.3721635043621063,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 196: paypal (61).png.... Completed region proposal. 1.23 sec.... Completed prediction. 0.40 sec.
# Dissimilarity score: 0.4090732932090759,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 197: paypal (62).png.... Completed region proposal. 1.23 sec.... Completed prediction. 0.40 sec.
# Dissimilarity score: 0.4090732932090759,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 198: paypal (64).png.... Completed region proposal. 1.29 sec.... Completed prediction. 0.49 sec.
# Dissimilarity score: 0.3839432895183563,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 199: paypal (63).png.... Completed region proposal. 1.30 sec.... Completed prediction. 0.49 sec.
# Dissimilarity score: 0.3839432895183563,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 200: paypal (66).png.... Completed region proposal. 2.02 sec.... Completed prediction. 1.19 sec.
# Dissimilarity score: 0.3206615447998047,  Class predicted: paypal_1.png,   Woo! :D
# Loaded image 201: paypal (65).png.... Completed region proposal. 2.04 sec.... Completed prediction. 1.17 sec.
# Dissimilarity score: 0.3206615447998047,  Class predicted: paypal_1.png,   Woo! :D
# Loaded image 202: paypal (67).png.... Completed region proposal. 0.62 sec.... Completed prediction. 0.09 sec.
# Dissimilarity score: 0.4203656315803528,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 203: paypal (68).png.... Completed region proposal. 2.63 sec.... Completed prediction. 1.82 sec.
# Dissimilarity score: 0.2800501883029938,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 204: paypal (69).png.... Completed region proposal. 0.80 sec.... Completed prediction. 0.06 sec.
# Dissimilarity score: 0.4398771822452545,  Class predicted: boa_1.png,   Aww :(
# Loaded image 205: paypal (70).png.... Completed region proposal. 3.58 sec.... Completed prediction. 2.56 sec.
# Dissimilarity score: 0.2795604169368744,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 206: paypal (71).png.... Completed region proposal. 2.33 sec.... Completed prediction. 1.70 sec.
# Dissimilarity score: 0.3399752378463745,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 207: paypal (72).png.... Completed region proposal. 1.02 sec.... Completed prediction. 0.20 sec.
# Dissimilarity score: 0.47435736656188965,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 208: paypal (5).png.... Completed region proposal. 1.24 sec.... Completed prediction. 0.32 sec.
# Dissimilarity score: 0.3577330708503723,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 209: paypal (37).png.... Completed region proposal. 2.87 sec.... Completed prediction. 0.76 sec.
# Dissimilarity score: 0.3301692306995392,  Class predicted: microsoft_3.png,   Aww :(
# Loaded image 210: paypal (38).png.... Completed region proposal. 3.76 sec.... Completed prediction. 1.13 sec.
# Dissimilarity score: 0.46307581663131714,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 211: paypal (39).png.... Completed region proposal. 9.86 sec.... Completed prediction. 5.03 sec.
# Dissimilarity score: 0.345194935798645,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 212: paypal (40).png.... Completed region proposal. 1.74 sec.... Completed prediction. 0.19 sec.
# Dissimilarity score: 0.3185722529888153,  Class predicted: paypal_1.png,   Woo! :D
# Loaded image 213: paypal (41).png.... Completed region proposal. 1.56 sec.... Completed prediction. 0.09 sec.
# Dissimilarity score: 0.318819522857666,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 214: paypal (42).png.... Completed region proposal. 2.55 sec.... Completed prediction. 0.74 sec.
# Dissimilarity score: 0.3483341336250305,  Class predicted: boa_2.png,   Aww :(
# Loaded image 215: paypal (43).png.... Completed region proposal. 2.38 sec.... Completed prediction. 0.47 sec.
# Dissimilarity score: 0.46266821026802063,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 216: paypal (44).png.... Completed region proposal. 2.32 sec.... Completed prediction. 0.47 sec.
# Dissimilarity score: 0.46266821026802063,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 217: paypal (45).png.... Completed region proposal. 1.53 sec.... Completed prediction. 0.07 sec.
# Dissimilarity score: 0.44609469175338745,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 218: paypal (46).png.... Completed region proposal. 1.47 sec.... Completed prediction. 0.05 sec.
# Dissimilarity score: 0.3471663296222687,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 219: paypal (47).png.... Completed region proposal. 2.70 sec.... Completed prediction. 0.67 sec.
# Dissimilarity score: 0.30614542961120605,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 220: paypal (48).png.... Completed region proposal. 7.68 sec.... Completed prediction. 3.59 sec.
# Dissimilarity score: 0.296118825674057,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 221: paypal (49).png.... Completed region proposal. 7.69 sec.... Completed prediction. 3.59 sec.
# Dissimilarity score: 0.296118825674057,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 222: paypal (50).png.... Completed region proposal. 1.67 sec.... Completed prediction. 0.15 sec.
# Dissimilarity score: 0.27063390612602234,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 223: paypal (51).png.... Completed region proposal. 10.53 sec.... Completed prediction. 5.34 sec.
# Dissimilarity score: 0.4865899682044983,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 224: paypal (52).png.... Completed region proposal. 2.34 sec.... Completed prediction. 0.43 sec.
# Dissimilarity score: 0.39722171425819397,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 225: paypal (54).png.... Completed region proposal. 10.39 sec.... Completed prediction. 5.52 sec.
# Dissimilarity score: 0.5178653597831726,  Class predicted: adobe_2.png,   Aww :(
# Loaded image 226: paypal (53).png.... Completed region proposal. 10.49 sec.... Completed prediction. 5.50 sec.
# Dissimilarity score: 0.5178653597831726,  Class predicted: adobe_2.png,   Aww :(
# Loaded image 227: paypal (10).png.... Completed region proposal. 10.60 sec.... Completed prediction. 5.73 sec.
# Dissimilarity score: 0.26556196808815,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 228: paypal (9).png.... Completed region proposal. 9.05 sec.... Completed prediction. 4.62 sec.
# Dissimilarity score: 0.289810448884964,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 229: paypal (12).png.... Completed region proposal. 3.97 sec.... Completed prediction. 1.19 sec.
# Dissimilarity score: 0.4785110056400299,  Class predicted: paypal_2.png,   Woo! :D
# Loaded image 230: paypal (14).png.... Completed region proposal. 10.86 sec.... Completed prediction. 5.86 sec.
# Dissimilarity score: 0.5192878842353821,  Class predicted: dropbox_1.png,   Aww :(
# Loaded image 231: paypal (4).png.... Completed region proposal. 2.63 sec.... Completed prediction. 0.54 sec.
# Dissimilarity score: 0.3109200596809387,  Class predicted: paypal_2.png,   Woo! :D
#
# Working in directory boa
# Loaded image 232: boa (3).jpg.... Completed region proposal. 6.75 sec.... Completed prediction. 3.94 sec.
# Dissimilarity score: 0.2546886205673218,  Class predicted: boa_2.png,   Woo! :D
# Loaded image 233: boa (1).jpg.... Completed region proposal. 6.75 sec.... Completed prediction. 3.39 sec.
# Dissimilarity score: 0.20865660905838013,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 234: boa (19).jpg.... Completed region proposal. 7.74 sec.... Completed prediction. 3.59 sec.
# Dissimilarity score: 0.31424635648727417,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 235: boa (48).png.... Completed region proposal. 0.20 sec.... Completed prediction. 0.45 sec.
# Dissimilarity score: 0.46447378396987915,  Class predicted: microsoft_4.png,   Aww :(
# Loaded image 236: boa (17).jpg.... Completed region proposal. 7.33 sec.... Completed prediction. 3.53 sec.
# Dissimilarity score: 0.31424635648727417,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 237: boa (58).png.... Completed region proposal. 2.65 sec.... Completed prediction. 1.66 sec.
# Dissimilarity score: 0.2859935462474823,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 238: boa (18).jpg.... Completed region proposal. 2.94 sec.... Completed prediction. 1.68 sec.
# Dissimilarity score: 0.42815181612968445,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 239: boa (16).jpg.... Completed region proposal. 19.95 sec.... Completed prediction. 9.42 sec.
# Dissimilarity score: 0.3050630986690521,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 240: boa (46).png.... Completed region proposal. 7.04 sec.... Completed prediction. 2.65 sec.
# Dissimilarity score: 0.45140016078948975,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 241: boa (54).png.... Completed region proposal. 2.15 sec.... Completed prediction. 0.58 sec.
# Dissimilarity score: 0.4185763895511627,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 242: boa (49).png.... Completed region proposal. 2.56 sec.... Completed prediction. 1.63 sec.
# Dissimilarity score: 0.4308406412601471,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 243: boa (51).png.... Completed region proposal. 24.94 sec.... Completed prediction. 4.40 sec.
# Dissimilarity score: 0.27579793334007263,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 244: boa (50).png.... Completed region proposal. 23.94 sec.... Completed prediction. 4.40 sec.
# Dissimilarity score: 0.27579793334007263,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 245: boa (52).png.... Completed region proposal. 24.82 sec.... Completed prediction. 4.39 sec.
# Dissimilarity score: 0.27579793334007263,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 246: boa (9).jpg.... Completed region proposal. 2.61 sec.... Completed prediction. 1.51 sec.
# Dissimilarity score: 0.2667172849178314,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 247: boa (57).png.... Completed region proposal. 2.59 sec.... Completed prediction. 0.84 sec.
# Dissimilarity score: 0.4001401960849762,  Class predicted: paypal_2.png,   Aww :(
# ...
# Loaded image 1204: facebook (74).png.... Completed region proposal. 1.42 sec.... Completed prediction. 0.66 sec.
# Dissimilarity score: 0.4979354441165924,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1205: facebook (76).png.... Completed region proposal. 1.24 sec.... Completed prediction. 0.36 sec.
# Dissimilarity score: 0.4699214994907379,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1206: facebook (75).png.... Completed region proposal. 1.23 sec.... Completed prediction. 0.36 sec.
# Dissimilarity score: 0.4699214994907379,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1207: facebook (77).png.... Completed region proposal. 1.57 sec.... Completed prediction. 0.67 sec.
# Dissimilarity score: 0.5301415920257568,  Class predicted: alibaba_2.png,   Aww :(
# Loaded image 1208: facebook (78).png.... Completed region proposal. 1.11 sec.... Completed prediction. 0.25 sec.
# Dissimilarity score: 0.4883972704410553,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1209: facebook (79).png.... Completed region proposal. 1.15 sec.... Completed prediction. 0.27 sec.
# Dissimilarity score: 0.4699214994907379,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1210: facebook (10).png.... Completed region proposal. 1.77 sec.... Completed prediction. 0.29 sec.
# Dissimilarity score: 0.64635169506073,  Class predicted: boa_2.png,   Aww :(
# Loaded image 1211: facebook (11).png.... Completed region proposal. 1.83 sec.... Completed prediction. 0.28 sec.
# Dissimilarity score: 0.64635169506073,  Class predicted: boa_2.png,   Aww :(
# Loaded image 1212: facebook (12).png.... Completed region proposal. 1.71 sec.... Completed prediction. 0.23 sec.
# Dissimilarity score: 0.64635169506073,  Class predicted: boa_2.png,   Aww :(
#
# Working in directory alibaba
# Loaded image 1213: alibaba (1).jpg.... Completed region proposal. 2.51 sec.... Completed prediction. 2.20 sec.
# Dissimilarity score: 0.4051324427127838,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1214: alibaba (49).png.... Completed region proposal. 4.65 sec.... Completed prediction. 1.78 sec.
# Dissimilarity score: 0.32980939745903015,  Class predicted: yahoo_1.png,   Aww :(
# Loaded image 1215: alibaba (48).png.... Completed region proposal. 5.76 sec.... Completed prediction. 2.30 sec.
# Dissimilarity score: 0.40010833740234375,  Class predicted: boa_1.png,   Aww :(
# Loaded image 1216: alibaba (46).png.... Completed region proposal. 0.64 sec.... Completed prediction. 0.38 sec.
# Dissimilarity score: 0.48268643021583557,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1217: alibaba (45).png.... Completed region proposal. 0.65 sec.... Completed prediction. 0.37 sec.
# Dissimilarity score: 0.48268643021583557,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1218: alibaba (47).png.... Completed region proposal. 0.96 sec.... Completed prediction. 0.51 sec.
# Dissimilarity score: 0.5047339200973511,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1219: alibaba (11).png.... Completed region proposal. 2.49 sec.... Completed prediction. 1.34 sec.
# Dissimilarity score: 0.41327404975891113,  Class predicted: microsoft_3.png,   Aww :(
# Loaded image 1220: alibaba (12).png.... Completed region proposal. 2.16 sec.... Completed prediction. 1.21 sec.
# Dissimilarity score: 0.4728899896144867,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1221: alibaba (13).png.... Completed region proposal. 2.26 sec.... Completed prediction. 1.13 sec.
# Dissimilarity score: 0.3576309382915497,  Class predicted: paypal_1.png,   Aww :(
# Loaded image 1222: alibaba (14).png.... Completed region proposal. 2.18 sec.... Completed prediction. 1.21 sec.
# Dissimilarity score: 0.31367045640945435,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1223: alibaba (15).png.... Completed region proposal. 2.19 sec.... Completed prediction. 1.23 sec.
# Dissimilarity score: 0.31367045640945435,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1224: alibaba (16).png.... Completed region proposal. 1.44 sec.... Completed prediction. 0.51 sec.
# Dissimilarity score: 0.3738192021846771,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1225: alibaba (17).png.... Completed region proposal. 1.98 sec.... Completed prediction. 0.97 sec.
# Dissimilarity score: 0.4012974500656128,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1226: alibaba (18).png.... Completed region proposal. 2.12 sec.... Completed prediction. 1.44 sec.
# Dissimilarity score: 0.4214509427547455,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1227: alibaba (19).png.... Completed region proposal. 2.61 sec.... Completed prediction. 1.98 sec.
# Dissimilarity score: 0.29534128308296204,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1228: alibaba (20).png.... Completed region proposal. 1.66 sec.... Completed prediction. 0.83 sec.
# Dissimilarity score: 0.5033833980560303,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1229: alibaba (21).png.... Completed region proposal. 1.09 sec.... Completed prediction. 0.30 sec.
# Dissimilarity score: 0.43615978956222534,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1230: alibaba (23).png.... Completed region proposal. 1.89 sec.... Completed prediction. 0.90 sec.
# Dissimilarity score: 0.42590534687042236,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1231: alibaba (22).png.... Completed region proposal. 1.91 sec.... Completed prediction. 0.90 sec.
# Dissimilarity score: 0.42590534687042236,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1232: alibaba (24).png.... Completed region proposal. 2.15 sec.... Completed prediction. 1.21 sec.
# Dissimilarity score: 0.4251005947589874,  Class predicted: alibaba_1.png,   Woo! :D
# Loaded image 1233: alibaba (25).png.... Completed region proposal. 1.98 sec.... Completed prediction. 1.01 sec.
# Dissimilarity score: 0.43756207823753357,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1234: alibaba (26).png.... Completed region proposal. 2.11 sec.... Completed prediction. 1.05 sec.
# Dissimilarity score: 0.4263528883457184,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1235: alibaba (27).png.... Completed region proposal. 1.88 sec.... Completed prediction. 1.10 sec.
# Dissimilarity score: 0.4263528883457184,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1236: alibaba (29).png.... Completed region proposal. 1.70 sec.... Completed prediction. 0.92 sec.
# Dissimilarity score: 0.5642256140708923,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1237: alibaba (28).png.... Completed region proposal. 1.69 sec.... Completed prediction. 0.92 sec.
# Dissimilarity score: 0.5642256140708923,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1238: alibaba (31).png.... Completed region proposal. 2.17 sec.... Completed prediction. 1.46 sec.
# Dissimilarity score: 0.4214509427547455,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1239: alibaba (30).png.... Completed region proposal. 2.12 sec.... Completed prediction. 1.46 sec.
# Dissimilarity score: 0.4214509427547455,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1240: alibaba (32).png.... Completed region proposal. 2.62 sec.... Completed prediction. 1.98 sec.
# Dissimilarity score: 0.29534128308296204,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1241: alibaba (33).png.... Completed region proposal. 2.15 sec.... Completed prediction. 1.46 sec.
# Dissimilarity score: 0.4214509427547455,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1242: alibaba (34).png.... Completed region proposal. 2.61 sec.... Completed prediction. 1.98 sec.
# Dissimilarity score: 0.29534128308296204,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1243: alibaba (35).png.... Completed region proposal. 2.63 sec.... Completed prediction. 1.98 sec.
# Dissimilarity score: 0.29534128308296204,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1244: alibaba (36).png.... Completed region proposal. 2.21 sec.... Completed prediction. 1.34 sec.
# Dissimilarity score: 0.3318246901035309,  Class predicted: paypal_1.png,   Aww :(
# Loaded image 1245: alibaba (39).png.... Completed region proposal. 2.04 sec.... Completed prediction. 1.27 sec.
# Dissimilarity score: 0.4332180321216583,  Class predicted: adobe_1.png,   Aww :(
# Loaded image 1246: alibaba (40).png.... Completed region proposal. 1.65 sec.... Completed prediction. 0.82 sec.
# Dissimilarity score: 0.5033833980560303,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1247: alibaba (41).png.... Completed region proposal. 1.63 sec.... Completed prediction. 0.97 sec.
# Dissimilarity score: 0.2586343288421631,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1248: alibaba (42).png.... Completed region proposal. 1.66 sec.... Completed prediction. 0.85 sec.
# Dissimilarity score: 0.5033833980560303,  Class predicted: alibaba_2.png,   Woo! :D
# Loaded image 1249: alibaba (44).png.... Completed region proposal. 2.15 sec.... Completed prediction. 1.00 sec.
# Dissimilarity score: 0.3674736022949219,  Class predicted: microsoft_4.png,   Aww :(
# Loaded image 1250: alibaba (43).png.... Completed region proposal. 1.81 sec.... Completed prediction. 0.78 sec.
# Dissimilarity score: 0.4160325527191162,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1251: alibaba (6).png.... Completed region proposal. 4.12 sec.... Completed prediction. 1.53 sec.
# Dissimilarity score: 0.3637828528881073,  Class predicted: paypal_1.png,   Aww :(
# Loaded image 1252: alibaba (7).png.... Completed region proposal. 3.37 sec.... Completed prediction. 1.06 sec.
# Dissimilarity score: 0.4230194091796875,  Class predicted: paypal_1.png,   Aww :(
# Loaded image 1253: alibaba (8).png.... Completed region proposal. 3.76 sec.... Completed prediction. 1.21 sec.
# Dissimilarity score: 0.43658584356307983,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1254: alibaba (9).png.... Completed region proposal. 4.82 sec.... Completed prediction. 2.08 sec.
# Dissimilarity score: 0.35370558500289917,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1255: alibaba (10).png.... Completed region proposal. 4.42 sec.... Completed prediction. 1.72 sec.
# Dissimilarity score: 0.47657132148742676,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1256: alibaba (1).png.... Completed region proposal. 3.30 sec.... Completed prediction. 1.15 sec.
# Dissimilarity score: 0.36434537172317505,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1257: alibaba (2).png.... Completed region proposal. 3.60 sec.... Completed prediction. 1.37 sec.
# Dissimilarity score: 0.3468882739543915,  Class predicted: yahoo_3.png,   Aww :(
# Loaded image 1258: alibaba (3).png.... Completed region proposal. 2.67 sec.... Completed prediction. 0.75 sec.
# Dissimilarity score: 0.4910965859889984,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1259: alibaba (4).png.... Completed region proposal. 4.84 sec.... Completed prediction. 2.11 sec.
# Dissimilarity score: 0.35370558500289917,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1260: alibaba (5).png.... Completed region proposal. 3.67 sec.... Completed prediction. 1.34 sec.
# Dissimilarity score: 0.3468882739543915,  Class predicted: yahoo_3.png,   Aww :(
#
# Working in directory linkedin
# Loaded image 1261: linkedin (1).jpg.... Completed region proposal. 2.70 sec.... Completed prediction. 2.43 sec.
# Dissimilarity score: 0.36645448207855225,  Class predicted: wellsfargo_1.png,   Aww :(
# Loaded image 1262: linkedin (3).png.... Completed region proposal. 1.73 sec.... Completed prediction. 1.24 sec.
# Dissimilarity score: 0.40234050154685974,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1263: linkedin (4).png.... Completed region proposal. 2.09 sec.... Completed prediction. 1.88 sec.
# Dissimilarity score: 0.4956050515174866,  Class predicted: adobe_1.png,   Aww :(
# Loaded image 1264: linkedin (5).png.... Completed region proposal. 2.08 sec.... Completed prediction. 1.89 sec.
# Dissimilarity score: 0.4956050515174866,  Class predicted: adobe_1.png,   Aww :(
# Loaded image 1265: linkedin (6).png.... Completed region proposal. 6.23 sec.... Completed prediction. 5.39 sec.
# Dissimilarity score: 0.34098368883132935,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1266: linkedin (1).png.... Completed region proposal. 6.22 sec.... Completed prediction. 5.37 sec.
# Dissimilarity score: 0.34098368883132935,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1267: linkedin (2).png.... Completed region proposal. 6.27 sec.... Completed prediction. 5.36 sec.
# Dissimilarity score: 0.34098368883132935,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1268: linkedin (11).png.... Completed region proposal. 3.86 sec.... Completed prediction. 2.52 sec.
# Dissimilarity score: 0.36474791169166565,  Class predicted: adobe_1.png,   Aww :(
# Loaded image 1269: linkedin (12).png.... Completed region proposal. 7.34 sec.... Completed prediction. 6.43 sec.
# Dissimilarity score: 0.2910017669200897,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1270: linkedin (13).png.... Completed region proposal. 3.93 sec.... Completed prediction. 2.51 sec.
# Dissimilarity score: 0.36474791169166565,  Class predicted: adobe_1.png,   Aww :(
# Loaded image 1271: linkedin (14).png.... Completed region proposal. 7.31 sec.... Completed prediction. 6.32 sec.
# Dissimilarity score: 0.2910017669200897,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1272: linkedin (15).png.... Completed region proposal. 6.02 sec.... Completed prediction. 5.83 sec.
# Dissimilarity score: 0.3222120702266693,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1273: linkedin (16).png.... Completed region proposal. 2.34 sec.... Completed prediction. 1.56 sec.
# Dissimilarity score: 0.2831808924674988,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1274: linkedin (17).png.... Completed region proposal. 3.00 sec.... Completed prediction. 2.45 sec.
# Dissimilarity score: 0.4956050515174866,  Class predicted: adobe_1.png,   Aww :(
# Loaded image 1275: linkedin (18).png.... Completed region proposal. 3.30 sec.... Completed prediction. 2.31 sec.
# Dissimilarity score: 0.3191758096218109,  Class predicted: microsoft_2.png,   Aww :(
# Loaded image 1276: linkedin (19).png.... Completed region proposal. 6.04 sec.... Completed prediction. 5.88 sec.
# Dissimilarity score: 0.3222120702266693,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1277: linkedin (20).png.... Completed region proposal. 2.52 sec.... Completed prediction. 1.85 sec.
# Dissimilarity score: 0.34769976139068604,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1278: linkedin (21).png.... Completed region proposal. 3.27 sec.... Completed prediction. 2.46 sec.
# Dissimilarity score: 0.4956050515174866,  Class predicted: adobe_1.png,   Aww :(
# Loaded image 1279: linkedin (23).png.... Completed region proposal. 1.69 sec.... Completed prediction. 0.69 sec.
# Dissimilarity score: 0.4046730399131775,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1280: linkedin (22).png.... Completed region proposal. 1.70 sec.... Completed prediction. 0.69 sec.
# Dissimilarity score: 0.4046730399131775,  Class predicted: paypal_2.png,   Aww :(
# Loaded image 1281: linkedin (7).png.... Completed region proposal. 8.45 sec.... Completed prediction. 4.51 sec.
# Dissimilarity score: 0.30031952261924744,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1282: linkedin (8).png.... Completed region proposal. 15.28 sec.... Completed prediction. 8.82 sec.
# Dissimilarity score: 0.27901357412338257,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1283: linkedin (9).png.... Completed region proposal. 15.38 sec.... Completed prediction. 8.80 sec.
# Dissimilarity score: 0.27621614933013916,  Class predicted: microsoft_1.png,   Aww :(
# Loaded image 1284: linkedin (10).png.... Completed region proposal. 8.35 sec.... Completed prediction. 4.50 sec.
# Dissimilarity score: 0.2683383524417877,  Class predicted: microsoft_1.png,   Aww :(
